# %% [markdown]
# # Spark Labs -- Python
#
#
# # Labs
#
# ### Pre-requisites
# Complete [README-python1.html](README-python1.html) first
#
# ###  1 - Python Primer
# - [1.1 - Hello Jupyter](01-python/hello-jupyter.ipynb)
# - [1.2 - Testing 123](01-python/testing-123.ipynb)
#
# ### 2 - Spark Intro
# - [2.1 - Run Spark](02-intro/2.1-install-spark-python.ipynb)
# - [2.2 - Spark Shell](02-intro/2.2-shell-python.ipynb)
#
# ### 3 - RDDs
# - [3.1 - RDD basics](03-rdd/3.1-rdd-basics-python.ipynb)
# - [3.6 - Caching](03-rdd/3.6-caching-python.ipynb)
# - **These RDD labs are for your reference (not done in the class)**
#     - [3.2 - Working with multiple RDDs](03-rdd/3.2-rdd-multi.ipynb)
#     - [3.3 - Key Value Pair RDDs](03-rdd/3.3-rdd-kv.ipynb)
#     - [3.4 - Map Reduce](03-rdd/3.4-mapreduce.ipynb)
#     - [3.5 - Clickstream processing](03-rdd/3.5-clickstream.ipynb)
#
#
# ### 4 - Dataframes
# - [4.1 - Dataframes](04-dataframe/4.1-dataframe-python.ipynb)
# - [4.2 - Spark SQL](04-dataframe/4.2-sql-python.ipynb)
# - [4.3 - Dataset](04-dataframe/4.3-dataset-python.ipynb)
# - [4.4 - Caching 2 SQL](04-dataframe/4.4-caching-2-sql-python.ipynb)
# - [4.5 - Spark & Hive (Hadoop)](04-dataframe/4.5-spark-and-hive-python.ipynb)
# - [4.6 - Data formats](04-dataframe/4.6-data-formats-python.ipynb)
#
# ### 5 - API
# - [5.1 - Submit first application](05-api/5.1-submit.md)
# - [5.2 - Mapreduce using API](05-api/5.2-mapreduce.md)
#
#
# ### Practice Labs for end of day 2
# - [Practice Lab 1 - Analyze Spark Commit logs](practice-labs/1-analyze-commit-logs-python.ipynb)
# - [Practice Lab 2 - Analyze clickstream logs](practice-labs/2-analyze-clickstream-python.ipynb)
#
#
# ### 6 - MLLib
# - [6.1 - Kmeans](06-mllib/kmeans/kmeans_mtcars.ipynb)
# - [6.2 - Recommendations](06-mllib/recs/README.md)
# - [6.3 - Classification](06-mllib/classification/README.md)
#
# ### 7 - GraphX
# - [7.1  - Influencers (Twitter)](07-graphx/7.1-influencer.ipynb)
# - [7.2  - Shortest path (in LinkedIn)](07-graphx/7.2-shortest-path.ipynb)
#
# ### 8 - Streaming
# - [8.1 - Streaming over TCP](08-streaming/8.1-over-tcp/README.ipynb)
# - [8.2 - Windowed Count](08-streaming/8.2-window/README.ipynb)
# - [8.3 - Kafka Streaming](08-streaming/8.3-kafka/README.ipynb)
# - 8.4 - Structured Streaming
#     * [8.4a - Structured Streaming 1](08-streaming/8.4-structured/README.ipynb)
#     * [8.4b - Structured Streaming 2 (JSON)](08-streaming/8.4-structured/README2.ipynb)
#
# ### 9 - Operations
# - [9.1 - Cluster setup](09-ops/9.1-cluster-setup.md)

# %% [markdown]
# <link rel='stylesheet' href='assets/css/main.css'/>
#
# Spark Labs -- Python
# ==========
# Welcome to Spark labs bundle.  This lab contains 2 parallel paths:
#
# 1. Scala
# 2. Python
#
# This is the base for the python labs.  If you want to go to the scala labs, go here:
#
# [Scala Labs](./README.md)
#
#
# Viewing the files:
# -----------------
# Most python labs can be done using jupyter notebooks.  They should all render properly in ordinary jupyter notebooks, however, jupyter notebooks may not work properly with spark code unless jupyter itslef is run in Pyspark.
#
# Markdown Files
# -------------
#
# Jupyter should render markdown files. However, if you want to load python files directly, we recommend the Markdown Preview Plus extension.
#
# * Get Chrome browser from : https://www.google.com/chrome/browser/desktop/
#
# * Install **Markdown Preview Plus Plugin** for Chrome.
# Go to this url in Chrome & click add to Chrome.
#     https://chrome.google.com/webstore/detail/markdown-preview-plus/febilkbfcbhebfnokafefeacimjdckgl?hl=en-US
# If this link does not work, search for markdown-preview-plus in https://chrome.google.com/webstore
#
# * Once installed, go to 'Window --> Extensions' menu of Chrome ;   Find 'Markdown Preview Plus' plugin ;  set 'Allow access to file urls'
#
# * Open any *.md file using Chrome (File --> Open)
#
#
# Editors
# -------
# We recommend using a 'programmer's editor' for editing files. Not everything can be done with jupyter. These editors have integrated file browser and allows navigating through files quickly.
#
# * For Windows : [Sublime](http://www.sublimetext.com/), [NodePad++](http://notepad-plus-plus.org/), [Textpad](http://www.textpad.com/)
#
# * For Mac : [Sublime](http://www.sublimetext.com/),  [TextWrangler](http://www.barebones.com/products/textwrangler/)
#
# * For Linux : [Sublime](http://www.sublimetext.com/), GEdit, Vim
# ----
# Labs
# ----
# 1. **Scala Primer**  (01-scala)
#    Ignore these as they are relevant only to learning scala language and this is the python path.
#
# 2. **Spark Intro**  (02-intro)
#     - [2.1 - Install and run Spark](02-intro/2.1-install-spark.ipynb)
#     - [2.2 - Spark Shell](02-intro/2.2-shell.ipynb)
#
# 3. **RDDs**  (03-rdd)
#     - [3.1 - RDD basics](03-rdd/3.1-rdd-basics.ipynb)
#     - [3.2 - Working with multiple RDDs](03-rdd/3.2-rdd-multi.ipynb)
#     - [3.3 - Key Value Pair RDDs](03-rdd/3.3-rdd-kv.ipynb)
#     - [3.4 - Map Reduce](03-rdd/3.4-mapreduce.ipynb)
#     - [3.5 - Clickstream processing](03-rdd/3.5-clickstream.ipynb)
#     - [3.6 - Caching](03-rdd/3.6-caching.ipynb)
#
# 4.  **Dataframes** (04-dataframe)
#     - [4.1 - Dataframes](04-dataframe/4.1-dataframe.ipynb)
#     - [4.2 - SQL](04-dataframe/4.2-sql.ipynb)
#     - [4.3 - Data formats](04-dataframe/4.3-data-formats.ipynb)
#     - [4.4 - Spark & Hive (Hadoop)](04-dataframe/4.4-spark-and-hive.ipynb)
#
# 5. **API** (05-api)
#     - [5.1 - Submit first application](05-api/5.1-submit.md)
#     - [5.2 - Mapreduce using API](05-api/5.2-mapreduce.md)
#
# 6. **MLLib**  (06-mllib)
#     - [6.1 - Kmeans](06-mllib/kmeans/kmeans_mtcars.ipynb)
#     - [6.2 - Recommendations](06-mllib/recs/README.md)
#     - [6.3 - Classification](06-mllib/classification/README.md)
#
# 7. **GraphX** (07-graphx)
#     - [7.1  - Influencers (Twitter)](07-graphx/7.1-influencer.ipynb)
#     - [7.2  - Shortest path (in LinkedIn)](07-graphx/7.2-shortest-path.ipynb)
#
# 8. **Streaming** (08-streaming)
#     - [8.1 - Streaming over TCP](08-streaming/8.1-over-tcp/README.ipynb)
#     - [8.2 - Windowed Count](08-streaming/8.2-window/README.ipynb)
#     - [8.3 - Kafka Streaming](08-streaming/8.3-kafka/README.ipynb)
#     - 8.4 - Structured Streaming
#         * [8.4a - Structured Streaming 1](08-streaming/8.4-structured/README.ipynb)
#         * [8.4b - Structured Streaming 2 (JSON)](08-streaming/8.4-structured/README2.ipynb)
#
# 9. **Operations** (09-ops)
#     - [9.1 - Cluster setup](09-ops/9.1-cluster-setup.md)
